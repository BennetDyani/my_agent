# %%
import chromadb

client = chromadb.Client()

# %%
collection = client.create_collection("news_articles")

# %%
collection.add(
    ids=["id1", "id2", "id3", "id4"],
   documents=[
    "Apple is leading in a smart phone game with iPhone sales up by 35%",
    "Tesla booked a minor profit of 1 billion $ in Q2",
    "Apples are high in fiber, vitamin C, and various antioxidants",
    "SpaceX got NASA contract worth 10 billion $",
    ]
)

# %%
#Fetch documents + embeddings
data = collection.get(
    include =["documents", "embeddings", "metadatas"]
)

#Print embeddings
for i, emb in enumerate(data["embeddings"]):
    print(f"\nDocument {i+1}")
    print("Text:", data["documents"][i])
    print("Embedding length:", len(emb))
    print("First 10 values:", emb[10])
# Out:
# Document 1
# Text: Apple is leading in a smart phone game with iPhone sales up by 35%
# Embedding length: 384
# First 10 values: 0.009548534639179707
#
# Document 2
# Text: Tesla booked a minor profit of 1 billion $ in Q2
# Embedding length: 384
# First 10 values: 0.06972504407167435
#
# Document 3
# Text: Apples are high in fiber, vitamin C, and various antioxidants
# Embedding length: 384
# First 10 values: 0.068117655813694
#
# Document 4
# Text: SpaceX got NASA contract worth 10 billion $
# Embedding length: 384
# First 10 values: -0.04723440110683441

# %%
results = collection.query(
    query_texts = ["This is a query related to Elon Musk"],
    n_results = 2
)
print(results)
# Out:
# {'ids': [['id2', 'id4']], 'embeddings': None, 'documents': [['Tesla booked a minor profit of 1 billion $ in Q2', 'SpaceX got NASA contract worth 10 billion $']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.5166926383972168, 1.5598335266113281]]}

# %%
results = collection.query(
    query_texts = ["I want to start eating healthy"],
    n_results = 2
)
print(results)
# Out:
# {'ids': [['id3', 'id1']], 'embeddings': None, 'documents': [['Apples are high in fiber, vitamin C, and various antioxidants', 'Apple is leading in a smart phone game with iPhone sales up by 35%']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.502198576927185, 2.0392706394195557]]}
